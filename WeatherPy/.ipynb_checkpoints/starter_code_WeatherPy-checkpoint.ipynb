# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
count = 1
sets = 1 
city_list = []
lat_list = []
lng_list = []
max_temp_list = []
humid_list = []
cloud_list = []
wind_list = []
country_list = []
date_list = []

print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        print(f"Processing Record {count} of Set {sets} | {city}")
        city_list.append(response["name"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response['coord']["lon"])
        max_temp_list.append(response["main"]["temp_max"])
        humid_list.append(response["main"]["humidity"])
        cloud_list.append(response["clouds"]["all"])
        wind_list.append(response["wind"]["speed"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
    except Exception:
        print("City not found. Skipping...")
    count += 1    
    if count == 51:
        count = 0
        sets = sets + 1
        time.sleep(60)
    
print("-----------------------------")    
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | lavrentiya
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 1 | mount gambier
# Processing Record 6 of Set 1 | karachi
# Processing Record 7 of Set 1 | kaliua
# Processing Record 8 of Set 1 | cabo san lucas
# Processing Record 9 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | waingapu
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | xining
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | bandeirantes
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | burkhala
# City not found. Skipping...
# Processing Record 19 of Set 1 | acarau
# Processing Record 20 of Set 1 | halmstad
# Processing Record 21 of Set 1 | san quintin
# Processing Record 22 of Set 1 | nome
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | kerteh
# City not found. Skipping...
# Processing Record 28 of Set 1 | beringovskiy
# Processing Record 29 of Set 1 | ovalle
# Processing Record 30 of Set 1 | dhidhdhoo
# Processing Record 31 of Set 1 | san cristobal
# Processing Record 32 of Set 1 | alamosa
# Processing Record 33 of Set 1 | banff
# Processing Record 34 of Set 1 | ingham
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | hovd
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | vardo
# Processing Record 41 of Set 1 | richards bay
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | gold coast
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | necochea
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | constitucion
# Processing Record 0 of Set 2 | port elizabeth
# Processing Record 1 of Set 2 | wajir
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | belmonte
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | walvis bay
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | agva
# City not found. Skipping...
# Processing Record 9 of Set 2 | faanui
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | solina
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | dickinson
# Processing Record 16 of Set 2 | tecoanapa
# Processing Record 17 of Set 2 | porto novo
# Processing Record 18 of Set 2 | lanzhou
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 2 | kindia
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | penzance
# Processing Record 28 of Set 2 | ozark
# Processing Record 29 of Set 2 | matay
# Processing Record 30 of Set 2 | assiniboia
# Processing Record 31 of Set 2 | cuamba
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | jalu
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | ivankiv
# Processing Record 40 of Set 2 | sinnamary
# Processing Record 41 of Set 2 | le port
# Processing Record 42 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 43 of Set 2 | iwanai
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | zyryanka
# Processing Record 46 of Set 2 | fortuna
# Processing Record 47 of Set 2 | ahipara
# Processing Record 48 of Set 2 | lagoa
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | baft
# Processing Record 0 of Set 3 | viedma
# Processing Record 1 of Set 3 | margate
# Processing Record 2 of Set 3 | shilovo
# Processing Record 3 of Set 3 | yoichi
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | port hardy
# Processing Record 6 of Set 3 | ca mau
# Processing Record 7 of Set 3 | bodden town
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 3 | nabire
# Processing Record 12 of Set 3 | awbari
# Processing Record 13 of Set 3 | codrington
# Processing Record 14 of Set 3 | alekseyevsk
# Processing Record 15 of Set 3 | tipuani
# Processing Record 16 of Set 3 | skjervoy
# Processing Record 17 of Set 3 | birjand
# Processing Record 18 of Set 3 | shingu
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | bilma
# Processing Record 21 of Set 3 | ulladulla
# Processing Record 22 of Set 3 | saint-augustin
# Processing Record 23 of Set 3 | kavieng
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | cabedelo
# Processing Record 27 of Set 3 | bay-khaak
# Processing Record 28 of Set 3 | tongliao
# Processing Record 29 of Set 3 | kangaatsiaq
# Processing Record 30 of Set 3 | troitsko-pechorsk
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | oranjemund
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | iskateley
# Processing Record 35 of Set 3 | ponnani
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | aksarka
# Processing Record 38 of Set 3 | coruripe
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | astrea
# Processing Record 42 of Set 3 | vigia del fuerte
# Processing Record 43 of Set 3 | waddan
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | touros
# Processing Record 46 of Set 3 | ust-nera
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 3 | katangli
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | omboue
# Processing Record 0 of Set 4 | jojoima
# Processing Record 1 of Set 4 | poum
# Processing Record 2 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | todos santos
# Processing Record 5 of Set 4 | quang ngai
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | dingle
# Processing Record 8 of Set 4 | sao felix do xingu
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | nanakuli
# Processing Record 11 of Set 4 | leningradskiy
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | vangaindrano
# Processing Record 14 of Set 4 | coquimbo
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | zaranj
# Processing Record 17 of Set 4 | mahebourg
# Processing Record 18 of Set 4 | beloha
# Processing Record 19 of Set 4 | dukat
# Processing Record 20 of Set 4 | kargat
# Processing Record 21 of Set 4 | egvekinot
# Processing Record 22 of Set 4 | manggar
# Processing Record 23 of Set 4 | mogadishu
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | laguna
# Processing Record 27 of Set 4 | dunedin
# Processing Record 28 of Set 4 | arraial do cabo
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | nuevitas
# Processing Record 31 of Set 4 | faya
# Processing Record 32 of Set 4 | empangeni
# Processing Record 33 of Set 4 | sechura
# Processing Record 34 of Set 4 | manicore
# Processing Record 35 of Set 4 | burbach
# Processing Record 36 of Set 4 | brae
# Processing Record 37 of Set 4 | inhapim
# Processing Record 38 of Set 4 | gat
# Processing Record 39 of Set 4 | oktyabrskiy
# Processing Record 40 of Set 4 | quartz hill
# Processing Record 41 of Set 4 | nyagan
# Processing Record 42 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 4 | la palma
# Processing Record 44 of Set 4 | khasan
# Processing Record 45 of Set 4 | tiksi
# Processing Record 46 of Set 4 | schweinfurt
# Processing Record 47 of Set 4 | pospelikha
# Processing Record 48 of Set 4 | saint anthony
# Processing Record 49 of Set 4 | burica
# City not found. Skipping...
# Processing Record 50 of Set 4 | banda aceh
# Processing Record 0 of Set 5 | ust-kulom
# Processing Record 1 of Set 5 | luanda
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | formosa do rio preto
# Processing Record 4 of Set 5 | union
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | sinjar
# Processing Record 7 of Set 5 | pevek
# Processing Record 8 of Set 5 | tuktoyaktuk
# Processing Record 9 of Set 5 | ajdabiya
# Processing Record 10 of Set 5 | krasnyy chikoy
# Processing Record 11 of Set 5 | soe
# Processing Record 12 of Set 5 | mar del plata
# Processing Record 13 of Set 5 | port blair
# Processing Record 14 of Set 5 | thinadhoo
# Processing Record 15 of Set 5 | ketchikan
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | boueni
# Processing Record 18 of Set 5 | rusape
# Processing Record 19 of Set 5 | sliac
# City not found. Skipping...
# Processing Record 20 of Set 5 | panguna
# Processing Record 21 of Set 5 | sur
# Processing Record 22 of Set 5 | georgetown
# Processing Record 23 of Set 5 | hamilton
# Processing Record 24 of Set 5 | sanmenxia
# Processing Record 25 of Set 5 | hofn
# Processing Record 26 of Set 5 | east london
# Processing Record 27 of Set 5 | comodoro rivadavia
# Processing Record 28 of Set 5 | tamiahua
# Processing Record 29 of Set 5 | chunoyar
# Processing Record 30 of Set 5 | clara
# Processing Record 31 of Set 5 | rio grande
# Processing Record 32 of Set 5 | henties bay
# Processing Record 33 of Set 5 | abnub
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | bathsheba
# Processing Record 36 of Set 5 | ilulissat
# Processing Record 37 of Set 5 | lorengau
# Processing Record 38 of Set 5 | chazuta
# Processing Record 39 of Set 5 | cap malheureux
# Processing Record 40 of Set 5 | arman
# Processing Record 41 of Set 5 | dikson
# Processing Record 42 of Set 5 | grand gaube
# Processing Record 43 of Set 5 | amod
# Processing Record 44 of Set 5 | ayagoz
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | adrar
# Processing Record 47 of Set 5 | neyyattinkara
# Processing Record 48 of Set 5 | solnechnyy
# Processing Record 49 of Set 5 | presidencia roque saenz pena
# Processing Record 50 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 0 of Set 6 | ikwiriri
# Processing Record 1 of Set 6 | cocorit
# Processing Record 2 of Set 6 | kalianget
# Processing Record 3 of Set 6 | marinette
# Processing Record 4 of Set 6 | bud
# Processing Record 5 of Set 6 | clyde river
# Processing Record 6 of Set 6 | jinchang
# Processing Record 7 of Set 6 | erzin
# Processing Record 8 of Set 6 | severnyy
# Processing Record 9 of Set 6 | kalmunai
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | mayumba
# Processing Record 12 of Set 6 | venice
# Processing Record 13 of Set 6 | verkhnevilyuysk
# Processing Record 14 of Set 6 | yaonahuac
# Processing Record 15 of Set 6 | napasar
# Processing Record 16 of Set 6 | fonte boa
# Processing Record 17 of Set 6 | nong kung si
# Processing Record 18 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 6 | plettenberg bay
# Processing Record 20 of Set 6 | rocha
# Processing Record 21 of Set 6 | neftcala
# Processing Record 22 of Set 6 | barcelos
# Processing Record 23 of Set 6 | oro valley
# Processing Record 24 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 6 | champerico
# Processing Record 26 of Set 6 | yumen
# Processing Record 27 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 6 | pokhara
# Processing Record 30 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 6 | flin flon
# Processing Record 32 of Set 6 | ballina
# Processing Record 33 of Set 6 | kruisfontein
# Processing Record 34 of Set 6 | sitka
# Processing Record 35 of Set 6 | stornoway
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | quixada
# Processing Record 38 of Set 6 | hailin
# Processing Record 39 of Set 6 | tigil
# Processing Record 40 of Set 6 | ostrovnoy
# Processing Record 41 of Set 6 | kurilsk
# Processing Record 42 of Set 6 | labuan
# Processing Record 43 of Set 6 | kloulklubed
# Processing Record 44 of Set 6 | price
# Processing Record 45 of Set 6 | arlit
# Processing Record 46 of Set 6 | inzhavino
# Processing Record 47 of Set 6 | meulaboh
# Processing Record 48 of Set 6 | san rafael
# Processing Record 49 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 6 | alofi
# Processing Record 0 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | langarud
# Processing Record 2 of Set 7 | guerrero negro
# Processing Record 3 of Set 7 | metro
# Processing Record 4 of Set 7 | krasnoselkup
# Processing Record 5 of Set 7 | aldama
# Processing Record 6 of Set 7 | port lincoln
# Processing Record 7 of Set 7 | marzuq
# Processing Record 8 of Set 7 | eirunepe
# Processing Record 9 of Set 7 | vestmanna
# Processing Record 10 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 7 | bonavista
# Processing Record 12 of Set 7 | camacha
# Processing Record 13 of Set 7 | suntar
# Processing Record 14 of Set 7 | khatanga
# Processing Record 15 of Set 7 | kasangulu
# Processing Record 16 of Set 7 | buta
# Processing Record 17 of Set 7 | zhangjiakou
# Processing Record 18 of Set 7 | araouane
# Processing Record 19 of Set 7 | jaciara
# Processing Record 20 of Set 7 | pleshanovo
# Processing Record 21 of Set 7 | narsaq
# Processing Record 22 of Set 7 | sikonge
# Processing Record 23 of Set 7 | bjornevatn
# Processing Record 24 of Set 7 | tabou
# Processing Record 25 of Set 7 | sabang
# Processing Record 26 of Set 7 | ialibu
# Processing Record 27 of Set 7 | roma
# Processing Record 28 of Set 7 | castro
# Processing Record 29 of Set 7 | maragogi
# Processing Record 30 of Set 7 | belaya gora
# Processing Record 31 of Set 7 | autun
# Processing Record 32 of Set 7 | monrovia
# Processing Record 33 of Set 7 | andenes
# Processing Record 34 of Set 7 | aripuana
# Processing Record 35 of Set 7 | kasongo-lunda
# Processing Record 36 of Set 7 | pueblo rico
# Processing Record 37 of Set 7 | nikolskoye
# Processing Record 38 of Set 7 | nantucket
# Processing Record 39 of Set 7 | tierra blanca
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | minamata
# Processing Record 42 of Set 7 | pontes e lacerda
# Processing Record 43 of Set 7 | klamath falls
# Processing Record 44 of Set 7 | kabansk
# Processing Record 45 of Set 7 | kapit
# Processing Record 46 of Set 7 | olafsvik
# Processing Record 47 of Set 7 | zhigalovo
# Processing Record 48 of Set 7 | bhopal
# Processing Record 49 of Set 7 | kushima
# Processing Record 50 of Set 7 | marietta
# Processing Record 0 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 1 of Set 8 | mangit
# Processing Record 2 of Set 8 | billings
# Processing Record 3 of Set 8 | mendeleyevo
# Processing Record 4 of Set 8 | hambantota
# Processing Record 5 of Set 8 | ossora
# Processing Record 6 of Set 8 | pereslavl-zalesskiy
# Processing Record 7 of Set 8 | peque
# Processing Record 8 of Set 8 | zabol
# Processing Record 9 of Set 8 | panama city
# Processing Record 10 of Set 8 | ixtapa
# Processing Record 11 of Set 8 | shimoda
# Processing Record 12 of Set 8 | giyani
# Processing Record 13 of Set 8 | saskylakh
# Processing Record 14 of Set 8 | yeppoon
# Processing Record 15 of Set 8 | pagudpud
# Processing Record 16 of Set 8 | zambezi
# Processing Record 17 of Set 8 | bouloupari
# Processing Record 18 of Set 8 | koshurnikovo
# Processing Record 19 of Set 8 | bar-le-duc
# Processing Record 20 of Set 8 | fez
# Processing Record 21 of Set 8 | tautira
# Processing Record 22 of Set 8 | ornskoldsvik
# Processing Record 23 of Set 8 | swan river
# Processing Record 24 of Set 8 | qazvin
# Processing Record 25 of Set 8 | sao francisco de assis
# Processing Record 26 of Set 8 | vostok
# Processing Record 27 of Set 8 | bayir
# Processing Record 28 of Set 8 | marrakesh
# Processing Record 29 of Set 8 | morant bay
# Processing Record 30 of Set 8 | auki
# Processing Record 31 of Set 8 | homer
# Processing Record 32 of Set 8 | boden
# Processing Record 33 of Set 8 | lazaro cardenas
# Processing Record 34 of Set 8 | abu dhabi
# Processing Record 35 of Set 8 | melbourne
# Processing Record 36 of Set 8 | lanxi
# Processing Record 37 of Set 8 | marsh harbour
# Processing Record 38 of Set 8 | pangai
# Processing Record 39 of Set 8 | nelson bay
# Processing Record 40 of Set 8 | portland
# Processing Record 41 of Set 8 | luderitz
# Processing Record 42 of Set 8 | inhambane
# Processing Record 43 of Set 8 | mandurah
# Processing Record 44 of Set 8 | dalby
# Processing Record 45 of Set 8 | ko samui
# Processing Record 46 of Set 8 | salalah
# Processing Record 47 of Set 8 | kapan
# Processing Record 48 of Set 8 | kharp
# Processing Record 49 of Set 8 | tual
# Processing Record 50 of Set 8 | awjilah
# Processing Record 0 of Set 9 | alta floresta
# Processing Record 1 of Set 9 | coalcoman
# City not found. Skipping...
# Processing Record 2 of Set 9 | covina
# Processing Record 3 of Set 9 | nioro
# Processing Record 4 of Set 9 | pishva
# Processing Record 5 of Set 9 | jutai
# Processing Record 6 of Set 9 | kalevala
# Processing Record 7 of Set 9 | westport
# Processing Record 8 of Set 9 | antalaha
# Processing Record 9 of Set 9 | torzhok
# Processing Record 10 of Set 9 | pavlodar
# Processing Record 11 of Set 9 | mill valley
# Processing Record 12 of Set 9 | methoni
# Processing Record 13 of Set 9 | hammerfest
# Processing Record 14 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 9 | upernavik
# Processing Record 16 of Set 9 | antofagasta
# Processing Record 17 of Set 9 | aykhal
# Processing Record 18 of Set 9 | baghmara
# Processing Record 19 of Set 9 | nova olimpia
# Processing Record 20 of Set 9 | pacifica
# Processing Record 21 of Set 9 | ducheng
# Processing Record 22 of Set 9 | kirakira
# Processing Record 23 of Set 9 | samarai
# Processing Record 24 of Set 9 | cidreira
# Processing Record 25 of Set 9 | synya
# Processing Record 26 of Set 9 | tete
# Processing Record 27 of Set 9 | vao
# Processing Record 28 of Set 9 | termiz
# Processing Record 29 of Set 9 | coihaique
# Processing Record 30 of Set 9 | korla
# Processing Record 31 of Set 9 | ryki
# Processing Record 32 of Set 9 | quipapa
# Processing Record 33 of Set 9 | vizimyary
# City not found. Skipping...
# Processing Record 34 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 9 | mitsamiouli
# Processing Record 36 of Set 9 | san felipe
# Processing Record 37 of Set 9 | ahuimanu
# Processing Record 38 of Set 9 | tilichiki
# Processing Record 39 of Set 9 | chingirlau
# Processing Record 40 of Set 9 | huarmey
# Processing Record 41 of Set 9 | sistranda
# Processing Record 42 of Set 9 | iberia
# Processing Record 43 of Set 9 | krasnovishersk
# Processing Record 44 of Set 9 | phayao
# Processing Record 45 of Set 9 | roebourne
# Processing Record 46 of Set 9 | fairbanks
# Processing Record 47 of Set 9 | stromness
# Processing Record 48 of Set 9 | umm lajj
# Processing Record 49 of Set 9 | den helder
# Processing Record 50 of Set 9 | sainte-anne-des-monts
# Processing Record 0 of Set 10 | mushie
# Processing Record 1 of Set 10 | mpophomeni
# Processing Record 2 of Set 10 | oistins
# Processing Record 3 of Set 10 | yunhe
# Processing Record 4 of Set 10 | the valley
# Processing Record 5 of Set 10 | tezu
# Processing Record 6 of Set 10 | daru
# Processing Record 7 of Set 10 | koboldo
# City not found. Skipping...
# Processing Record 8 of Set 10 | keetmanshoop
# Processing Record 9 of Set 10 | coahuayana
# Processing Record 10 of Set 10 | thunder bay
# Processing Record 11 of Set 10 | whitehorse
# Processing Record 12 of Set 10 | mombasa
# Processing Record 13 of Set 10 | eydhafushi
# Processing Record 14 of Set 10 | atasu
# Processing Record 15 of Set 10 | gorontalo
# Processing Record 16 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 10 | alice springs
# Processing Record 18 of Set 10 | norman wells
# Processing Record 19 of Set 10 | khani
# Processing Record 20 of Set 10 | manica
# Processing Record 21 of Set 10 | lisakovsk
# Processing Record 22 of Set 10 | ghanzi
# Processing Record 23 of Set 10 | charters towers
# Processing Record 24 of Set 10 | sisimiut
# Processing Record 25 of Set 10 | panjab
# Processing Record 26 of Set 10 | moron
# Processing Record 27 of Set 10 | kieta
# Processing Record 28 of Set 10 | carutapera
# Processing Record 29 of Set 10 | bereda
# Processing Record 30 of Set 10 | yar-sale
# Processing Record 31 of Set 10 | rovaniemi
# Processing Record 32 of Set 10 | namtsy
# Processing Record 33 of Set 10 | iguaba grande
# Processing Record 34 of Set 10 | baykit
# Processing Record 35 of Set 10 | shirokiy
# Processing Record 36 of Set 10 | lasa
# Processing Record 37 of Set 10 | fort myers beach
# Processing Record 38 of Set 10 | padang
# Processing Record 39 of Set 10 | santa vitoria do palmar
# Processing Record 40 of Set 10 | husavik
# Processing Record 41 of Set 10 | liaozhong
# Processing Record 42 of Set 10 | sabha
# Processing Record 43 of Set 10 | arona
# Processing Record 44 of Set 10 | okitipupa
# Processing Record 45 of Set 10 | diapaga
# Processing Record 46 of Set 10 | erenhot
# Processing Record 47 of Set 10 | alekseyevka
# Processing Record 48 of Set 10 | uspenka
# Processing Record 49 of Set 10 | chitral
# Processing Record 50 of Set 10 | el balyana
# City not found. Skipping...
# Processing Record 0 of Set 11 | saint-pierre
# Processing Record 1 of Set 11 | qaqortoq
# Processing Record 2 of Set 11 | shrewsbury
# Processing Record 3 of Set 11 | maturin
# Processing Record 4 of Set 11 | pocone
# Processing Record 5 of Set 11 | zhaoqing
# Processing Record 6 of Set 11 | mahon
# Processing Record 7 of Set 11 | murgab
# Processing Record 8 of Set 11 | little current
# Processing Record 9 of Set 11 | lakes entrance
# Processing Record 10 of Set 11 | anadyr
# Processing Record 11 of Set 11 | petatlan
# Processing Record 12 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 11 | faridan
# City not found. Skipping...
# Processing Record 14 of Set 11 | cochrane
# Processing Record 15 of Set 11 | junction city
# Processing Record 16 of Set 11 | nara
# Processing Record 17 of Set 11 | el badari
# City not found. Skipping...
# Processing Record 18 of Set 11 | road town
# Processing Record 19 of Set 11 | manta
# Processing Record 20 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 11 | la asuncion
# Processing Record 23 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 11 | enid
# Processing Record 25 of Set 11 | chama
# Processing Record 26 of Set 11 | ponta delgada
# Processing Record 27 of Set 11 | santa cruz
# Processing Record 28 of Set 11 | kaabong
# Processing Record 29 of Set 11 | santa rosa
# Processing Record 30 of Set 11 | kampene
# Processing Record 31 of Set 11 | martorell
# Processing Record 32 of Set 11 | toora-khem
# Processing Record 33 of Set 11 | zell am see
# City not found. Skipping...
# Processing Record 35 of Set 11 | puerto escondido
# Processing Record 36 of Set 11 | moose factory
# Processing Record 37 of Set 11 | carauari
# Processing Record 38 of Set 11 | havelock
# Processing Record 39 of Set 11 | venado tuerto
# Processing Record 40 of Set 11 | kenai
# Processing Record 41 of Set 11 | varzea da palma
# Processing Record 42 of Set 11 | envira
# Processing Record 43 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 44 of Set 11 | mae sot
# Processing Record 45 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 46 of Set 11 | gasa
# Processing Record 47 of Set 11 | jiazi
# Processing Record 48 of Set 11 | aksu
# Processing Record 49 of Set 11 | berlevag
# Processing Record 50 of Set 11 | sipovo
# Processing Record 0 of Set 12 | chernyy yar
# Processing Record 1 of Set 12 | kelvington
# Processing Record 2 of Set 12 | poquoson
# Processing Record 3 of Set 12 | yerbogachen
# Processing Record 4 of Set 12 | ondjiva
# Processing Record 5 of Set 12 | sweetwater
# Processing Record 6 of Set 12 | oussouye
# Processing Record 7 of Set 12 | sohbatpur
# Processing Record 8 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 12 | najran
# Processing Record 10 of Set 12 | rorvik
# Processing Record 11 of Set 12 | batemans bay
# Processing Record 12 of Set 12 | saint-joseph
# Processing Record 13 of Set 12 | howard springs
# Processing Record 14 of Set 12 | camingawan
# Processing Record 15 of Set 12 | litovko
# Processing Record 16 of Set 12 | general pico
# Processing Record 17 of Set 12 | taitung
# Processing Record 18 of Set 12 | imbituba
# Processing Record 19 of Set 12 | tazovskiy
# Processing Record 20 of Set 12 | chiang kham
# Processing Record 21 of Set 12 | inverell
# Processing Record 22 of Set 12 | havre-saint-pierre
# Processing Record 23 of Set 12 | south venice
# Processing Record 24 of Set 12 | epernay
# Processing Record 25 of Set 12 | turochak
# Processing Record 26 of Set 12 | kuopio
# Processing Record 27 of Set 12 | weiser
# Processing Record 28 of Set 12 | plouzane
# Processing Record 29 of Set 12 | bucerias
# Processing Record 30 of Set 12 | berlin
# Processing Record 31 of Set 12 | reyes
# Processing Record 32 of Set 12 | trairi
# Processing Record 33 of Set 12 | itarema
# Processing Record 34 of Set 12 | bacoor
# Processing Record 35 of Set 12 | marawi
# Processing Record 36 of Set 12 | karratha
# Processing Record 37 of Set 12 | kampot
# Processing Record 38 of Set 12 | palmer
# Processing Record 39 of Set 12 | kikinda
# Processing Record 40 of Set 12 | zhezkazgan
# Processing Record 41 of Set 12 | matara
# Processing Record 42 of Set 12 | kesova gora
# Processing Record 43 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 12 | goundam
# Processing Record 45 of Set 12 | waitati
# Processing Record 46 of Set 12 | natchez
# Processing Record 47 of Set 12 | svetlyy
# Processing Record 48 of Set 12 | karakol
# Processing Record 49 of Set 12 | qui nhon
# Processing Record 50 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 0 of Set 13 | jardim
# Processing Record 1 of Set 13 | nogales
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {"City": city_list, "Lat": lat_list, "Lng":lng_list, "Max Temp":max_temp_list, 
                "Humidity":humid_list, "Cloudiness":cloud_list, "Wind Speed":wind_list,
                "Country":country_list, "Date":date_list
               }
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cherskiy  68.7500  161.3000    -24.23        86         100
# 1     Lavrentiya  65.5833 -171.0000      0.57        85         100
# 2        Ushuaia -54.8000  -68.3000     64.40        32          40
# 3  Mount Gambier -37.8333  140.7667     71.60        46          95
# 4        Karachi  24.9056   67.0822     53.60        24           0
#
#    Wind Speed Country        Date
# 0        7.36      RU  1611518356
# 1        2.59      RU  1611518356
# 2       28.77      AR  1611518356
# 3        5.75      AU  1611518356
# 4       11.50      PK  1611518356

# %%
## Export data into a csv
weather_df.to_csv("output_data/cities.csv")

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  564.000000  564.000000  564.000000  564.000000  564.000000  564.000000
# mean    20.140707   14.856853   49.842394   73.429078   56.352837    7.976933
# std     33.328458   90.402038   33.710545   20.234687   40.048966    5.711691
# min    -54.800000 -179.166700  -59.800000   11.000000    0.000000    0.180000
# 25%     -7.112500  -65.029075   30.990000   64.000000   10.000000    3.440000
# 50%     24.686150   20.345800   61.000000   78.000000   75.000000    6.910000
# 75%     48.698550   94.705350   77.362500   89.000000   97.000000   11.270000
# max     78.218600  179.316700  105.870000  100.000000  100.000000   33.380000
#
#                Date
# count  5.640000e+02
# mean   1.611519e+09
# std    3.706347e+02
# min    1.611518e+09
# 25%    1.611518e+09
# 50%    1.611519e+09
# 75%    1.611519e+09
# max    1.611520e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
## Starter code did a .describe() again here for some reason
## weather_df.describe() ??

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df.loc[weather_df["Humidity"] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
clean_city_data = weather_df[weather_df["Humidity"] <= 100]

# %%
clean_city_data.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cherskiy  68.7500  161.3000    -24.23        86         100
# 1     Lavrentiya  65.5833 -171.0000      0.57        85         100
# 2        Ushuaia -54.8000  -68.3000     64.40        32          40
# 3  Mount Gambier -37.8333  140.7667     71.60        46          95
# 4        Karachi  24.9056   67.0822     53.60        24           0
#
#    Wind Speed Country        Date
# 0        7.36      RU  1611518356
# 1        2.59      RU  1611518356
# 2       28.77      AR  1611518356
# 3        5.75      AU  1611518356
# 4       11.50      PK  1611518356

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = date.today()
today_date = today.strftime("%m/%d/%Y")
today_date
# Out:
# '01/24/2021'

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp"], edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
## Another way to get today's date ^
plt.grid()
plt.savefig("output_data/lat_temp.png")
plt.show()

## Is this the date of the data or our date today 
## Give outline to the points to better visualize -- do for all plots

# %% [markdown]
# The above plot shows the relationship between the latitude and the max temp of that city at that latitude. As the latitude approaches 0, the equator, warmer temperatures are found, which makes sense. As the latitutde increases positively, temperature decreases significantly. Interstingly, as you move away from the equator in the southern hemisphere, there is not as significant of a decrease in temperatures, likely due to the fewer data points.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity"], edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({today_date})")
plt.grid()
plt.savefig("output_data/lat_hum.png")
plt.show()
## Need to add date to chart title -- currently in Unix, need to convert
## Is this the date of the data or our date today

# %% [markdown]
# This chart plots the percent humidity against the latitude of the cities. The cities furtherst from the equator tend to have lower percent humidities, which makes sense because they are closer to the poles. However, once you are within +/- 40 degrees latitude, the humidity tends to fall heavily within 60-100%.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness"], edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({today_date})")
plt.grid()
plt.savefig("output_data/lat_cloud.png")
plt.show()
## Need to add date to chart title -- currently in Unix, need to convert
## Is this the date of the data or our date today

# %% [markdown]
# There does not appear to be much of a trend, upon visual inspection of the chart, between the latitude and the cloudiness of the cities at that point.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Wind Speed"], edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed ({today_date})")
plt.grid()
plt.savefig("output_data/lat_wind.png")
plt.show()
## Need to add date to chart title -- currently in Unix, need to convert
## Is this the date of the data or our date today

# %% [markdown]
# The code looks at the relationship between the latitute and the wind speed of the cities found at said latitude. Again, there does not appear to be a strong relationship between the variables, as most data is grouped in the 0-15 mph range for latitutes -40 to ~70.

# %% [markdown]
# ## Linear Regression

# %%
# Separating data into northern hemisphere
northern_hem_data = clean_city_data[clean_city_data["Lat"] >= 0]
northern_hem_data.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cherskiy  68.7500  161.3000    -24.23        86         100
# 1      Lavrentiya  65.5833 -171.0000      0.57        85         100
# 4         Karachi  24.9056   67.0822     53.60        24           0
# 6  Cabo San Lucas  22.8909 -109.9124     73.00        49          20
# 7          Albany  42.6001  -73.9662     24.01        37          46
#
#    Wind Speed Country        Date
# 0        7.36      RU  1611518356
# 1        2.59      RU  1611518356
# 4       11.50      PK  1611518356
# 6       10.36      MX  1611518343
# 7        5.01      US  1611518281

# %%
# Separating data into southern hemisphere 
southern_hem_data = clean_city_data[clean_city_data["Lat"] < 0]
southern_hem_data.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2        Ushuaia -54.8000  -68.3000     64.40        32          40
# 3  Mount Gambier -37.8333  140.7667     71.60        46          95
# 5         Kaliua  -5.0606   31.7936     65.98        92          99
# 8        Mataura -46.1927  168.8643     60.01        83          98
# 9       Waingapu  -9.6567  120.2641     78.01        77          86
#
#    Wind Speed Country        Date
# 2       28.77      AR  1611518356
# 3        5.75      AU  1611518356
# 5        0.18      TZ  1611518356
# 8       15.01      NZ  1611518357
# 9        6.69      ID  1611518357

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hem_data["Lat"]
y_values = northern_hem_data["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title(f"Northern Hemisphere - City Latitude vs. Max Temp ({today_date})")
print(f"The r-value is: {rvalue}")
plt.savefig("output_data/nor_lat_temp.png")
plt.show()
# Out:
# The r-value is: -0.8492717011597765

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hem_data["Lat"]
y_values = southern_hem_data["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title(f"Southern Hemisphere - City Latitude vs. Max Temp ({today_date})")
print(f"The r-value is: {rvalue}")
plt.savefig("output_data/sou_lat_temp.png")
plt.show()
# Out:
# The r-value is: 0.3182582048713159

# %% [markdown]
# Both of the above plots agree with logic as, in the northern hemisphere, as latitude increases and you head North, temperatures would decrease on average. For the southern hemisphere, the plot also makes sense, though the relationship is not as strong, as noted by the r-value, and likely due to the fewer data points, as temperatures increase on average, as you approach the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hem_data["Lat"]
y_values = northern_hem_data["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,53),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Northern Hemisphere - City Latitude vs. Humidity (%) ({today_date})")
print(f"The r-value is: {rvalue}")
plt.savefig("output_data/nor_lat_hum.png")
plt.show()
# Out:
# The r-value is: 0.32642090718883227

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hem_data["Lat"]
y_values = southern_hem_data["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,45),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Southern Hemisphere - City Latitude vs. Humidity (%) ({today_date})")
print(f"The r-value is: {rvalue}")
plt.savefig("output_data/sou_lat_hum.png")
plt.show()
# Out:
# The r-value is: 0.40491804894616296

# %% [markdown]
# The regression analysis indicates a weak positive relationship between percent humidity and increasing latitude for the northern hemisphere. As for the southern hemisphere, there is also a weak positive relationship between decreasing latitude, approaching the equator, and the percent humidity. This result seems like it would make more sense given the warmer temperatures would create more humid conditions, unlike the data represented by the Northern Hemisphere plot.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hem_data["Lat"]
y_values = northern_hem_data["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Northern Hemisphere - City Latitude vs. Cloudiness (%) ({today_date})")
print(f"The r-value is: {rvalue}")
plt.savefig("output_data/nor_lat_cloud.png")
plt.show()
# Out:
# The r-value is: 0.18848944419320976

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hem_data["Lat"]
y_values = southern_hem_data["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,42),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Southern Hemisphere - City Latitude vs. Cloudiness (%) ({today_date})")
print(f"The r-value is: {rvalue}")
plt.savefig("output_data/sou_lat_cloud.png")
plt.show()
# Out:
# The r-value is: 0.4114273400779703

# %% [markdown]
# The Northern Hemisphere plot indicates a very weak positive relationship between increasing city latitude and the cloudiness, indicated by the r-value. However, the Southern Hemisphere plot indicates a stronger positive relationship between decreasing city latitude and increasing cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hem_data["Lat"]
y_values = northern_hem_data["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Northern Hemisphere - City Latitude vs. Wind Speed (mph) ({today_date})")
print(f"The r-value is: {rvalue}")
plt.savefig("output_data/nor_lat_wind.png")
plt.show()
# Out:
# The r-value is: 0.04034864227437588

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hem_data["Lat"]
y_values = southern_hem_data["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Southern Hemisphere - City Latitude vs. Wind Speed (mph) ({today_date})")
print(f"The r-value is: {rvalue}")
plt.savefig("output_data/sou_lat_wind.png")
plt.show()
# Out:
# The r-value is: -0.35465411153535176

# %% [markdown]
# There is a nearly non-existent relationship between the increasing city latitude and the wind speed of cities in the Northern Hemisphere, given the fact that the calculated r-value is less than 0.1. The Southern Hemisphere data in fact yields a negative relationship between decreasing latitude and increasing wind speeds.
